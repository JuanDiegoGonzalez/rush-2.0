# %% [markdown]
# ## Clasificador: KNN

# %% [markdown]
# Implementado por: Sergio Ramírez Vélez

# %% [markdown]
# ### 1. Importación de librerías

# %%
# Librerías para manejo de datos
import pandas as pd
pd.set_option('display.max_columns', 25) # Número máximo de columnas a mostrar
pd.set_option('display.max_rows', 50) # Numero máximo de filas a mostar
import numpy as np
np.random.seed(3301)
# Para preparar los datos
from sklearn.preprocessing import LabelEncoder
# Para usar KNN como clasificador
from sklearn.neighbors import KNeighborsClassifier
# Para realizar la separación del conjunto de aprendizaje en entrenamiento y test.
from sklearn.model_selection import train_test_split
# Para evaluar el modelo
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import plot_confusion_matrix
# Para búsqueda de hiperparámetros
from sklearn.model_selection import GridSearchCV
# Para la validación cruzada
from sklearn.model_selection import KFold 
# Librerías para la visualización
import matplotlib.pyplot as plt
# Seaborn
import seaborn as sns
# Sklearn
from sklearn import tree
# Librería para balancear
from imblearn.over_sampling import SMOTE

# %% [markdown]
# ### 2. Carga de los datos

# %%
# Se cargan los datos.
# Ubicación de los datos, deben estar en la misma carpeta que este notebook
db_location = "202210_Laboratorio1_data_Datos_Clasificacion_2022.csv"

# Se leen los datos, estan separados con ;
data = pd.read_csv(db_location, sep=';', encoding = 'utf-8', na_values = '-', dtype='object')

# %% [markdown]
# ### 3. Descripción y análisis de los datos

# %%
# Dimensiones de los datos
data.shape
# Out:
# (100000, 27)

# %%
# Mostrar los datos
data.head()
# Out:
#   Diabetes_012 HighBP HighChol CholCheck BMI Smoker Stroke  \
# 0            0      1        1         1  40      1      0
# 1            0      0        0         0  25      1      0
# 2            0      1        1         1  28      0      0
# 3            0      1        0         1  27      0      0
# 4            0      1        1         1  24      0      0
#
#   HeartDiseaseorAttack PhysActivity Fruits Veggies HvyAlcoholConsump  ...  \
# 0                    0            0      0       1                 0  ...
# 1                    0            1      0       0                 0  ...
# 2                    0            0      1       0                 0  ...
# 3                    0            1      1       1                 0  ...
# 4                    0            1      1       1                 0  ...
#
#   MentHlth PhysHlth DiffWalk Sex Age Education Income Unnamed: 22 Unnamed: 23  \
# 0       18       15        1   0   9         4      3         NaN         NaN
# 1        0        0        0   0   7         6      1         NaN         NaN
# 2       30       30        1   0   9         4      8         NaN         NaN
# 3        0        0        0   0  11         3      6         NaN         NaN
# 4        3        0        0   0  11         5      4         NaN         NaN
#
#   Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
# [5 rows x 27 columns]

# %%
# Imprimimos los diferentes tipos de las columnas. Todos son objetos.
data.dtypes
# Out:
# Diabetes_012            object
# HighBP                  object
# HighChol                object
# CholCheck               object
# BMI                     object
# Smoker                  object
# Stroke                  object
# HeartDiseaseorAttack    object
# PhysActivity            object
# Fruits                  object
# Veggies                 object
# HvyAlcoholConsump       object
# AnyHealthcare           object
# NoDocbcCost             object
# GenHlth                 object
# MentHlth                object
# PhysHlth                object
# DiffWalk                object
# Sex                     object
# Age                     object
# Education               object
# Income                  object
# Unnamed: 22             object
# Unnamed: 23             object
# Unnamed: 24             object
# Unnamed: 25             object
# Unnamed: 26             object
# dtype: object

# %%
# Y hacer una decripción de los datos
data.describe()
# Out:
#        Diabetes_012 HighBP HighChol CholCheck    BMI Smoker Stroke  \
# count         99969  99963    99983     99969  99965  99964  99974
# unique            5      4        4         4     94      4      4
# top               0      0        0         1     27      0      0
# freq          84078  56544    56814     96330   9624  55426  95818
#
#        HeartDiseaseorAttack PhysActivity Fruits Veggies HvyAlcoholConsump  \
# count                 99971        99967  99968   99976             99976
# unique                    4            4      4       4                 4
# top                       0            1      1       1                 0
# freq                  90617        76135  63639   81464             94248
#
#         ... MentHlth PhysHlth DiffWalk    Sex    Age Education Income  \
# count   ...    99971    99961    99976  99981  99970     99960  99991
# unique  ...       48       53        4      4     15         8     10
# top     ...        0        0        0      0      9         6      8
# freq    ...    68495    62518    83320  56163  13114     43815  36920
#
#        Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# count            0           0           0           0           0
# unique           0           0           0           0           0
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
#
# [4 rows x 27 columns]

# %%
# Se observa que hay ausencias significativas en algunas columnas
data.isnull().sum()
# Out:
# Diabetes_012                31
# HighBP                      37
# HighChol                    17
# CholCheck                   31
# BMI                         35
# Smoker                      36
# Stroke                      26
# HeartDiseaseorAttack        29
# PhysActivity                33
# Fruits                      32
# Veggies                     24
# HvyAlcoholConsump           24
# AnyHealthcare               26
# NoDocbcCost                 35
# GenHlth                     30
# MentHlth                    29
# PhysHlth                    39
# DiffWalk                    24
# Sex                         19
# Age                         30
# Education                   40
# Income                       9
# Unnamed: 22             100000
# Unnamed: 23             100000
# Unnamed: 24             100000
# Unnamed: 25             100000
# Unnamed: 26             100000
# dtype: int64

# %% [markdown]
# ### 4. Limpieza y preparación de los datos

# %%
# Es recomendable que todos los pasos de limpieza y preparación se realicen sobre otro archivo
data_t = data
# Los datos se convierten a formato numérico
data_t[data_t.columns] = data_t[data_t.columns].apply(pd.to_numeric, errors='coerce')

# %%
# Se deciden eliminar las columnas vacías, no tienen información útil para el modelo
data_t = data_t.dropna(how='all', axis='columns')
# Se eliminan los datos duplicados: 5842 filas
data_t = data_t.drop_duplicates()
# Se eliminan los registros con ausencias: 1067 filas
data_t = data_t.dropna()

# %%
data_t.shape
# Out:
# (93091, 22)

# %%
data_t.describe()
# Out:
#        Diabetes_012        HighBP      HighChol     CholCheck           BMI  \
# count  93091.000000  93091.000000  93091.000000  93091.000000  93091.000000
# mean       0.316142      0.451268      0.443792      0.961769     28.522575
# std        0.715661      0.497622      0.496833      0.191755      7.848531
# min        0.000000      0.000000      0.000000      0.000000    -35.000000
# 25%        0.000000      0.000000      0.000000      1.000000     24.000000
# 50%        0.000000      0.000000      0.000000      1.000000     27.000000
# 75%        0.000000      1.000000      1.000000      1.000000     32.000000
# max        2.000000      1.000000      1.000000      1.000000     98.000000
#
#              Smoker        Stroke  HeartDiseaseorAttack  PhysActivity  \
# count  93091.000000  93091.000000          93091.000000  93091.000000
# mean       0.461043      0.043925              0.098742      0.747623
# std        0.498483      0.204929              0.298317      0.434379
# min        0.000000      0.000000              0.000000      0.000000
# 25%        0.000000      0.000000              0.000000      0.000000
# 50%        0.000000      0.000000              0.000000      1.000000
# 75%        1.000000      0.000000              0.000000      1.000000
# max        1.000000      1.000000              1.000000      1.000000
#
#              Fruits       Veggies  HvyAlcoholConsump  AnyHealthcare  \
# count  93091.000000  93091.000000       93091.000000   93091.000000
# mean       0.622595      0.804675           0.060070       0.947417
# std        0.484740      0.396453           0.237618       0.223201
# min        0.000000      0.000000           0.000000       0.000000
# 25%        0.000000      1.000000           0.000000       1.000000
# 50%        1.000000      1.000000           0.000000       1.000000
# 75%        1.000000      1.000000           0.000000       1.000000
# max        1.000000      1.000000           1.000000       1.000000
#
#         NoDocbcCost       GenHlth      MentHlth      PhysHlth      DiffWalk  \
# count  93091.000000  93091.000000  93091.000000  93091.000000  93091.000000
# mean       0.086883      2.561354      3.337820      4.458261      0.176601
# std        0.281665      1.065027      7.747141      9.145297      0.381333
# min        0.000000      1.000000    -37.000000    -43.000000      0.000000
# 25%        0.000000      2.000000      0.000000      0.000000      0.000000
# 50%        0.000000      2.000000      0.000000      0.000000      0.000000
# 75%        0.000000      3.000000      2.000000      3.000000      0.000000
# max        1.000000      5.000000     36.000000     42.000000      1.000000
#
#                 Sex           Age     Education        Income
# count  93091.000000  93091.000000  93091.000000  93091.000000
# mean       0.437540      8.129250      5.030529      6.000999
# std        0.496086      3.070138      0.989499      2.074328
# min        0.000000      1.000000      1.000000      1.000000
# 25%        0.000000      6.000000      4.000000      5.000000
# 50%        0.000000      8.000000      5.000000      7.000000
# 75%        1.000000     10.000000      6.000000      8.000000
# max        1.000000     13.000000      6.000000      8.000000

# %% [markdown]
# En este punto, se observa que algunas columnas tienen valores por fuera del rango indicado en el codebook, por lo que se procede a analizarlas con más detenimiento.

# %%
data_t.value_counts(['BMI'])
# Out:
# BMI
# 27.0    8802
# 26.0    7228
# 24.0    6875
# 28.0    6028
# 25.0    6026
#         ...
# 85.0       1
# 88.0       1
# 91.0       1
# 96.0       1
# 86.0       1
# Length: 92, dtype: int64

# %%
data_t.value_counts(['MentHlth'])
# Out:
# MentHlth
#  0.0        62115
#  2.0         5034
#  30.0        4528
#  5.0         3622
#  1.0         3387
#  3.0         3012
#  10.0        2462
#  15.0        2125
#  4.0         1508
#  20.0        1334
#  7.0         1227
#  25.0         494
#  14.0         445
#  6.0          397
#  8.0          234
#  12.0         167
#  28.0         159
#  21.0          92
#  16.0          66
#  29.0          63
#  18.0          54
#  22.0          47
#  9.0           39
#  24.0          36
#  26.0          34
#  36.0          27
# -21.0          26
#  27.0          25
# -33.0          25
# -27.0          25
# -29.0          25
#  34.0          24
#  32.0          23
# -25.0          23
# -19.0          22
# -35.0          21
# -31.0          20
#  13.0          19
#  11.0          17
#  23.0          16
# -17.0          15
# -23.0          15
#  17.0          14
# -15.0          13
#  19.0           9
# -37.0           6
# dtype: int64

# %%
data_t.value_counts(['PhysHlth'])
# Out:
# PhysHlth
#  0.0        56165
#  30.0        7394
#  2.0         5744
#  1.0         4285
#  3.0         3405
#             ...
# -21.0          13
# -25.0          13
#  42.0          13
#  19.0          10
# -17.0           2
# Length: 51, dtype: int64

# %% [markdown]
# Para la columna BMI, la mayoría de datos están dentro del rango válido. Sin embargo, para las columnas MentHlth y PhysHlth la mayoría de datos se encuentra fuera de rango (>1 y <30). Para cada caso, se le da un tratamiento distinto.

# %%
# BMI:
# Para las filas cuyo valor de BMI está fuera del rango válido, este se reemplaza con el promedio de todos los datos
data_t['BMI'] = np.where((data_t['BMI'] > 1) & (data_t['BMI'] < 99), data_t['BMI'], data_t['BMI'].mean()).tolist()

# %%
# MentHlth:
# Dado que una gran parte de los datos se encuentra fuera del rango válido, pero cerca a sus extremos,
# la mayoría de estos datos se reemplazan con el valor más cercano que esté dentro del rango de la siguiente manera:
# Los valores 0.0 y 1.0 se reemplazan con 2.0, y el valor 30.0 se reemplaza con 29.0
data_t['MentHlth'] = data_t['MentHlth'].replace(0, 2)
data_t['MentHlth'] = data_t['MentHlth'].replace(1, 2)
data_t['MentHlth'] = data_t['MentHlth'].replace(30, 29)

# Para las filas cuyo valor de MentHlth es menor a 0 o mayor a 30, estos se reemplazan con el promedio de todos los datos
data_t['MentHlth'] = np.where((data_t['MentHlth'] > 1) & (data_t['MentHlth'] < 30), data_t['MentHlth'], data_t['MentHlth'].mean()).tolist()

# %%
# PhysHlth:
# Dado que una gran parte de los datos se encuentra fuera del rango válido, pero cerca a sus extremos,
# la mayoría de estos datos se reemplazan con el valor más cercano que esté dentro del rango de la siguiente manera:
# Los valores 0.0 y 1.0 se reemplazan con 2.0, y el valor 30.0 se reemplaza con 29.0
data_t['PhysHlth'] = data_t['PhysHlth'].replace(0, 2)
data_t['PhysHlth'] = data_t['PhysHlth'].replace(1, 2)
data_t['PhysHlth'] = data_t['PhysHlth'].replace(30, 29)

# Para las filas cuyo valor de PhysHlth es menor a 0 o mayor a 30, estos se reemplazan con el promedio de todos los datos
data_t['PhysHlth'] = np.where((data_t['PhysHlth'] > 1) & (data_t['PhysHlth'] < 30), data_t['PhysHlth'], data_t['PhysHlth'].mean()).tolist()

# %%
data_t.describe()
# Out:
#        Diabetes_012        HighBP      HighChol     CholCheck           BMI  \
# count  93091.000000  93091.000000  93091.000000  93091.000000  93091.000000
# mean       0.316142      0.451268      0.443792      0.961769     28.668424
# std        0.715661      0.497622      0.496833      0.191755      7.332472
# min        0.000000      0.000000      0.000000      0.000000     12.000000
# 25%        0.000000      0.000000      0.000000      1.000000     24.000000
# 50%        0.000000      0.000000      0.000000      1.000000     27.000000
# 75%        0.000000      1.000000      1.000000      1.000000     32.000000
# max        2.000000      1.000000      1.000000      1.000000     98.000000
#
#              Smoker        Stroke  HeartDiseaseorAttack  PhysActivity  \
# count  93091.000000  93091.000000          93091.000000  93091.000000
# mean       0.461043      0.043925              0.098742      0.747623
# std        0.498483      0.204929              0.298317      0.434379
# min        0.000000      0.000000              0.000000      0.000000
# 25%        0.000000      0.000000              0.000000      0.000000
# 50%        0.000000      0.000000              0.000000      1.000000
# 75%        1.000000      0.000000              0.000000      1.000000
# max        1.000000      1.000000              1.000000      1.000000
#
#              Fruits       Veggies  HvyAlcoholConsump  AnyHealthcare  \
# count  93091.000000  93091.000000       93091.000000   93091.000000
# mean       0.622595      0.804675           0.060070       0.947417
# std        0.484740      0.396453           0.237618       0.223201
# min        0.000000      0.000000           0.000000       0.000000
# 25%        0.000000      1.000000           0.000000       1.000000
# 50%        1.000000      1.000000           0.000000       1.000000
# 75%        1.000000      1.000000           0.000000       1.000000
# max        1.000000      1.000000           1.000000       1.000000
#
#         NoDocbcCost       GenHlth      MentHlth      PhysHlth      DiffWalk  \
# count  93091.000000  93091.000000  93091.000000  93091.000000  93091.000000
# mean       0.086883      2.561354      4.714383      5.693918      0.176601
# std        0.281665      1.065027      6.795306      8.043471      0.381333
# min        0.000000      1.000000      2.000000      2.000000      0.000000
# 25%        0.000000      2.000000      2.000000      2.000000      0.000000
# 50%        0.000000      2.000000      2.000000      2.000000      0.000000
# 75%        0.000000      3.000000      2.000000      4.000000      0.000000
# max        1.000000      5.000000     29.000000     29.000000      1.000000
#
#                 Sex           Age     Education        Income
# count  93091.000000  93091.000000  93091.000000  93091.000000
# mean       0.437540      8.129250      5.030529      6.000999
# std        0.496086      3.070138      0.989499      2.074328
# min        0.000000      1.000000      1.000000      1.000000
# 25%        0.000000      6.000000      4.000000      5.000000
# 50%        0.000000      8.000000      5.000000      7.000000
# 75%        1.000000     10.000000      6.000000      8.000000
# max        1.000000     13.000000      6.000000      8.000000

# %%
data_t.value_counts(['BMI'])
# Out:
# BMI
# 27.0    8802
# 26.0    7228
# 24.0    6875
# 28.0    6028
# 25.0    6026
#         ...
# 85.0       1
# 86.0       1
# 88.0       1
# 91.0       1
# 96.0       1
# Length: 82, dtype: int64

# %%
data_t.value_counts(['MentHlth'])
# Out:
# MentHlth
# 2.000000     70536
# 29.000000     4591
# 5.000000      3622
# 3.000000      3012
# 10.000000     2462
# 15.000000     2125
# 4.000000      1508
# 20.000000     1334
# 7.000000      1227
# 25.000000      494
# 14.000000      445
# 6.000000       397
# 4.660064       310
# 8.000000       234
# 12.000000      167
# 28.000000      159
# 21.000000       92
# 16.000000       66
# 18.000000       54
# 22.000000       47
# 9.000000        39
# 24.000000       36
# 26.000000       34
# 27.000000       25
# 13.000000       19
# 11.000000       17
# 23.000000       16
# 17.000000       14
# 19.000000        9
# dtype: int64

# %%
data_t.value_counts(['PhysHlth'])
# Out:
# PhysHlth
# 2.000000     66194
# 29.000000     7487
# 3.000000      3405
# 5.000000      3039
# 10.000000     2236
# 15.000000     1885
# 4.000000      1781
# 7.000000      1756
# 20.000000     1307
# 14.000000      993
# 25.000000      570
# 6.000000       558
# 5.631533       365
# 8.000000       338
# 12.000000      241
# 21.000000      227
# 28.000000      208
# 18.000000       79
# 9.000000        73
# 26.000000       52
# 16.000000       52
# 22.000000       48
# 24.000000       40
# 17.000000       34
# 27.000000       32
# 13.000000       30
# 23.000000       28
# 11.000000       23
# 19.000000       10
# dtype: int64

# %% [markdown]
# ### 5. Construcción del modelo: KNN

# %%
# Se selecciona la variable objetivo, en este caso "Diabetes_012"
Y = data_t['Diabetes_012']
# Del conjunto de datos se elimina la variable "Diabetes_012"
X = data_t.drop(['Diabetes_012'], axis=1)

# %%
# Se normalizan los datos
X_n = X.copy()
X_n=(X_n-X_n.min())/(X_n.max()-X_n.min())
X_n.describe()
# Out:
#              HighBP      HighChol     CholCheck           BMI        Smoker  \
# count  93091.000000  93091.000000  93091.000000  93091.000000  93091.000000
# mean       0.451268      0.443792      0.961769      0.193819      0.461043
# std        0.497622      0.496833      0.191755      0.085261      0.498483
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      1.000000      0.139535      0.000000
# 50%        0.000000      0.000000      1.000000      0.174419      0.000000
# 75%        1.000000      1.000000      1.000000      0.232558      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#              Stroke  HeartDiseaseorAttack  PhysActivity        Fruits  \
# count  93091.000000          93091.000000  93091.000000  93091.000000
# mean       0.043925              0.098742      0.747623      0.622595
# std        0.204929              0.298317      0.434379      0.484740
# min        0.000000              0.000000      0.000000      0.000000
# 25%        0.000000              0.000000      0.000000      0.000000
# 50%        0.000000              0.000000      1.000000      1.000000
# 75%        0.000000              0.000000      1.000000      1.000000
# max        1.000000              1.000000      1.000000      1.000000
#
#             Veggies  HvyAlcoholConsump  AnyHealthcare   NoDocbcCost  \
# count  93091.000000       93091.000000   93091.000000  93091.000000
# mean       0.804675           0.060070       0.947417      0.086883
# std        0.396453           0.237618       0.223201      0.281665
# min        0.000000           0.000000       0.000000      0.000000
# 25%        1.000000           0.000000       1.000000      0.000000
# 50%        1.000000           0.000000       1.000000      0.000000
# 75%        1.000000           0.000000       1.000000      0.000000
# max        1.000000           1.000000       1.000000      1.000000
#
#             GenHlth      MentHlth      PhysHlth      DiffWalk           Sex  \
# count  93091.000000  93091.000000  93091.000000  93091.000000  93091.000000
# mean       0.390338      0.100533      0.136812      0.176601      0.437540
# std        0.266257      0.251678      0.297906      0.381333      0.496086
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.250000      0.000000      0.000000      0.000000      0.000000
# 50%        0.250000      0.000000      0.000000      0.000000      0.000000
# 75%        0.500000      0.000000      0.074074      0.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                 Age     Education        Income
# count  93091.000000  93091.000000  93091.000000
# mean       0.594104      0.806106      0.714428
# std        0.255845      0.197900      0.296333
# min        0.000000      0.000000      0.000000
# 25%        0.416667      0.600000      0.571429
# 50%        0.583333      0.800000      0.857143
# 75%        0.750000      1.000000      1.000000
# max        1.000000      1.000000      1.000000

# %%
# Se dividen los datos en entrenamiento y test
X_train, X_test, Y_train, Y_test = train_test_split(X_n, Y, test_size=0.2, random_state=0)

# %%
# Se balancean las clases
sm = SMOTE(random_state=42)
X_bal, Y_bal = sm.fit_resample(X_train, Y_train)

# %%
# Se fija el número de particiones: K = 5.
particiones = KFold(n_splits=5, shuffle=True, random_state = 0)

# %%
# Se establece el espacio de búsqueda de hiperparámetros
param_grid = {'n_neighbors': [3], 'p': [1, 2]}

# %%
# Se define el modelo. Se indica como parámetro que se quiere balancear las clases
clasificadorKNN = KNeighborsClassifier()

# %%
# Se utiliza GridSearch sobre el grid definido en la validación cruzada
mejor_modelo = GridSearchCV(clasificadorKNN, param_grid, cv=particiones)
# Se entrena el modelo
mejor_modelo.fit(X_bal, Y_bal)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=0, shuffle=True),
#              estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3], 'p': [1, 2]})

# %%
mejor_modelo.best_params_
# Out:
# {'n_neighbors': 3, 'p': 1}

# %%
modelo_final = mejor_modelo.best_estimator_
y_pred_test = modelo_final.predict(X_test)

# %%
print('Exactitud sobre test: %.2f' % accuracy_score(Y_test, y_pred_test))
# Out:
# Exactitud sobre test: 0.71

# %%
print(classification_report(Y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.78      0.82     15460
#          1.0       0.02      0.04      0.03       406
#          2.0       0.28      0.43      0.34      2753
#
#     accuracy                           0.71     18619
#    macro avg       0.39      0.42      0.40     18619
# weighted avg       0.77      0.71      0.74     18619
